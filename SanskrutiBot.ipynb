# %%
from langchain_community.document_loaders import TextLoader
loadder = TextLoader('data.txt',encoding="utf-8")
loadder

# %%
pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain_community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain_community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.4 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.7 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.6 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-text-splitters-1.1.2 langchain_community-0.4.2 pydantic-settings-2.15.0 requests-2.34.2

# %%
text_documents = loadder.load()
text_documents
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='Absolutely. For your project **“Enhancement of Nutrient Efficiency of Compost Through Microbial Augmentation,”** it is important to first understand composting as a whole—its types, feedstocks, operating conditions, and testing methods. Then you can explain why microbial augmentation is being introduced into your particular composting system.\n\n# 1. What is composting?\n\n**Composting is a controlled biological process in which microorganisms decompose biodegradable organic matter, mainly under aerobic conditions, and convert it into a relatively stable, humus-like material called compost.** ([US EPA][1])\n\nThe microorganisms involved include:\n\n* Bacteria\n* Fungi\n* Actinomycetes\n* Protozoa and other microbial communities\n* Earthworms in vermicomposting\n\nThe basic requirements are:\n\n**Carbon + Nitrogen + Oxygen + Moisture + Microorganisms + Suitable temperature → Stable compost**\n\nThe process generally passes through:\n\n**Organic waste → Mesophilic phase → Thermophilic phase → Cooling phase → Maturation/curing → Finished compost**\n\nDuring active composting, microorganisms consume organic matter and release heat. Properly managed thermophilic composting can reach approximately **55–71°C**, depending on the system and conditions, helping reduce pathogens and weed seeds. ([US EPA][2])\n\n---\n\n# 2. Why do we need composting?\n\nComposting provides several environmental and agricultural benefits.\n\n### Environmental benefits\n\n* Reduces organic waste sent to landfills.\n* Reduces methane generation associated with uncontrolled anaerobic decomposition in landfills.\n* Recycles nutrients.\n* Reduces the volume of biodegradable waste.\n* Produces a useful soil amendment.\n* Supports circular management of agricultural and food waste. ([US EPA][1])\n\n### Agricultural benefits\n\nFinished compost can:\n\n* Improve soil organic matter.\n* Improve soil structure.\n* Increase water-holding capacity.\n* Improve nutrient availability.\n* Support beneficial soil microorganisms.\n* Reduce dependence on some chemical soil amendments.\n* Improve soil fertility over time.\n\n---\n\n# 3. Basic principle of composting\n\nThe most important concept is the balance between **carbon-rich ("brown") and nitrogen-rich ("green") materials**.\n\n### Carbon-rich materials\n\nExamples:\n\n* Dry leaves\n* Straw\n* Wheat husk\n* Rice straw\n* Sawdust\n* Wood chips\n* Paper/cardboard\n* Dry agricultural residues\n\nThey provide **carbon and structural porosity**.\n\n### Nitrogen-rich materials\n\nExamples:\n\n* Cow dung\n* Poultry manure\n* Green leaves\n* Vegetable waste\n* Fruit waste\n* Grass clippings\n* Food waste\n\nThey provide nitrogen required for microbial growth.\n\nEPA describes the basic feedstock balance as carbon-rich materials such as dry leaves/wood chips combined with nitrogen-rich materials such as food scraps and grass clippings. ([US EPA][1])\n\n---\n\n# 4. Major types of composting\n\nThere isn\'t just one classification. Composting can be classified according to **oxygen availability, physical arrangement, technology, scale, or biological agent**.\n\nThe major practical systems are:\n\n1. Aerobic composting\n2. Windrow composting\n3. Static pile composting\n4. Aerated static pile composting\n5. In-vessel composting\n6. Vermicomposting\n7. Passive composting/home composting\n8. Anaerobic biological treatment — technically different from conventional aerobic composting and better described as anaerobic digestion when biogas production is the objective.\n\n---\n\n# 5. Aerobic composting\n\nAerobic composting is the most common scientific basis for conventional composting.\n\n### Principle\n\nMicroorganisms use oxygen to break down organic matter.\n\nSimplified:\n\n**Organic matter + O₂ → CO₂ + H₂O + heat + stabilized organic matter**\n\n### Typical operating requirements\n\n| Parameter     | Typical practical range/target                                        |\n|  ...

# %%
import os
# Text splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)
finalDocuments = textSplitter.split_documents(text_documents)
finalDocuments
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='Absolutely. For your project **“Enhancement of Nutrient Efficiency of Compost Through Microbial Augmentation,”** it is important to first understand composting as a whole—its types, feedstocks,'),
#  Document(metadata={'source': 'data.txt'}, page_content='types, feedstocks, operating conditions, and testing methods. Then you can explain why microbial augmentation is being introduced into your particular composting system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='# 1. What is composting?'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Composting is a controlled biological process in which microorganisms decompose biodegradable organic matter, mainly under aerobic conditions, and convert it into a relatively stable, humus-like'),
#  Document(metadata={'source': 'data.txt'}, page_content='stable, humus-like material called compost.** ([US EPA][1])'),
#  Document(metadata={'source': 'data.txt'}, page_content='The microorganisms involved include:\n\n* Bacteria\n* Fungi\n* Actinomycetes\n* Protozoa and other microbial communities\n* Earthworms in vermicomposting\n\nThe basic requirements are:'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Carbon + Nitrogen + Oxygen + Moisture + Microorganisms + Suitable temperature → Stable compost**\n\nThe process generally passes through:'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Organic waste → Mesophilic phase → Thermophilic phase → Cooling phase → Maturation/curing → Finished compost**'),
#  Document(metadata={'source': 'data.txt'}, page_content='During active composting, microorganisms consume organic matter and release heat. Properly managed thermophilic composting can reach approximately **55–71°C**, depending on the system and conditions,'),
#  Document(metadata={'source': 'data.txt'}, page_content='and conditions, helping reduce pathogens and weed seeds. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 2. Why do we need composting?\n\nComposting provides several environmental and agricultural benefits.\n\n### Environmental benefits'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Reduces organic waste sent to landfills.\n* Reduces methane generation associated with uncontrolled anaerobic decomposition in landfills.\n* Recycles nutrients.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Reduces the volume of biodegradable waste.\n* Produces a useful soil amendment.\n* Supports circular management of agricultural and food waste. ([US EPA][1])'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Agricultural benefits\n\nFinished compost can:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Improve soil organic matter.\n* Improve soil structure.\n* Increase water-holding capacity.\n* Improve nutrient availability.\n* Support beneficial soil microorganisms.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Reduce dependence on some chemical soil amendments.\n* Improve soil fertility over time.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 3. Basic principle of composting\n\nThe most important concept is the balance between **carbon-rich ("brown") and nitrogen-rich ("green") materials**.\n\n### Carbon-rich materials\n\nExamples:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Examples:\n\n* Dry leaves\n* Straw\n* Wheat husk\n* Rice straw\n* Sawdust\n* Wood chips\n* Paper/cardboard\n* Dry agricultural residues\n\nThey provide **carbon and structural porosity**.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Nitrogen-rich materials\n\nExamples:\n\n* Cow dung\n* Poultry manure\n* Green leaves\n* Vegetable waste\n* Fruit waste\n* Grass clippings\n* Food waste'),
#  Document(metadata={'source': 'data.txt'}, page_content='They provide nitrogen required for microbial growth.'),
#  Document(metadata={'source': 'data.txt'}, page_content='EPA describes the basic feedstock balance as carbon-rich materials such as dry leaves/wood chips combined with nitrogen-rich materials such as food scraps and grass clippings. ([US EPA][1])\n\n---'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 4. Major types of composting'),
#  Document(metadata={'source': 'data.txt'}, page_content="There isn't just one classification. Composting can be classified according to **oxygen availability, physical arrangement, technology, scale, or biological agent**."),
#  Document(metadata={'source': 'data.txt'}, page_content='The major practical systems are:'),
#  Document(metadata={'source': 'data.txt'}, page_content='1. Aerobic composting\n2. Windrow composting\n3. Static pile composting\n4. Aerated static pile composting\n5. In-vessel composting\n6. Vermicomposting\n7. Passive composting/home composting'),
#  Document(metadata={'source': 'data.txt'}, page_content='8. Anaerobic biological treatment — technically different from conventional aerobic composting and better described as anaerobic digestion when biogas production is the objective.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 5. Aerobic composting\n\nAerobic composting is the most common scientific basis for conventional composting.\n\n### Principle\n\nMicroorganisms use oxygen to break down organic matter.\n\nSimplified:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Simplified:\n\n**Organic matter + O₂ → CO₂ + H₂O + heat + stabilized organic matter**\n\n### Typical operating requirements'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Parameter     | Typical practical range/target                                        |\n| ------------- | --------------------------------------------------------------------- |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Oxygen        | Adequate aerobic supply                                               |\n| Moisture      | Approximately 50–60% is commonly used                                 |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Temperature   | Active thermophilic phase often ~45–65°C                              |\n| C:N ratio     | Commonly targeted around 25–30:1 initially                            |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| pH            | Generally near neutral to mildly alkaline during later stages         |\n| Particle size | Small enough for surface area but large enough to maintain air spaces |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Turning       | As required for aeration and heat/moisture management                 |'),
#  Document(metadata={'source': 'data.txt'}, page_content='The exact optimum varies with feedstock and process. Excess water fills air spaces and can create anaerobic zones, while excessively dry material suppresses microbial activity. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Advantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Relatively fast decomposition.\n* Good pathogen reduction when thermophilic conditions are achieved.\n* Produces stable compost.\n* Suitable for agricultural residues, food waste and manure.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Nutrient recycling.\n* Can be operated at household to industrial scale.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Requires moisture management.\n* Requires oxygen/aeration management.\n* Improper C:N balance can slow decomposition.\n* Excess moisture can create odour.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Nitrogen can be lost if the pile is poorly managed.\n* Requires monitoring for consistent quality.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 6. Windrow composting'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/poY8vwhvUR4iDvQmhuW0L68rCwb2z2uqajKHAtn04sLX85IXn72yfihDrdIXiyFJ00LTAwpBssgij25hlmwCjL3qnniUJ5Ik1XjRGlK-PpgGeuMwavU_cVf7vclK1i6tu2BDhjorPj-MF3dqxhYV9ov'),
#  Document(metadata={'source': 'data.txt'}, page_content='DhjorPj-MF3dqxhYV9ovdkTl-N3lGA7Q-D1BV1IYZjJZifFPRPToBlMLv4bbd?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/TjshLJxO-orYA31ZKbS9LrJLLH5LgVczs3hh5GIOr1qiDvvGQn-mTdhjWgXTaoCCEB2JiSCg2wrPKC5T4RTGdfIl2PMdM93exP8GWxv8SzGyEfdTRsw4AU7eTkS6uDVauWubNY0rKOc4r9cA7SpDiBl'),
#  Document(metadata={'source': 'data.txt'}, page_content='bNY0rKOc4r9cA7SpDiBlvAvkIdeSnIML4o7iEz7gi6uuiaqn0h5sEH63fTtyi?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/f8v3Mx1CWeOyUEx30ExPPtvSllwyADSSaxROdETFfU5d1dboVobvKoGMw4giMVdNBdSo__-CmCmXVJmMa0z9plv2ouEPnp_9hprCma6QTuOJQ5FtB4UM4DwzpIabhl0N5dzIc1-5rJQpyW35TLOOVjA'),
#  Document(metadata={'source': 'data.txt'}, page_content='Ic1-5rJQpyW35TLOOVjAvfqgI5IAtr_swEiuUS4mQHq3z45HF3PdUBPKuczC_?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/LQ3QcaBViiCL0ABPGyouKh6hPbnd00tXlY-d6qlh0M8n-UurVlJk17AVN_FbY7AxhATQEFfxx2PoZuLCmQ0TfQ4_S9vZ7vUbMOlvbX6yMHk1SIAgU0Rte_-IWtbNU7jxRPrlXAKlGslkc6u5gZVyjaE'),
#  Document(metadata={'source': 'data.txt'}, page_content='lXAKlGslkc6u5gZVyjaEgtq0ttDFAt_jfVaIT1OoNSVA_cNnB58_DSkZyb55o?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/wmPy7sso3bBp_eP6HikNGA2os4_bC49Xh3lonfgL12YA4ig8_oWXAe6Fy21MO7z6ADLiIE_soeCz-vs7yYM12KsBqw5FrdrnireUcQQByjdRWthICESNeD8OCrgv1FiXUSAEM7Qd6eWF2NGtJ8SvHZk'),
#  Document(metadata={'source': 'data.txt'}, page_content='EM7Qd6eWF2NGtJ8SvHZkjTg3tiKjVbLoyTlfuLkg0F9gLksIoVDnvQ-k3JnT9?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/mcYg1RHMBK0Ri81gOxA9rGa1JAeSE8v7mScr6ghkwARHVUQBzlyDa5xvwWdOEaTr8JD-5uPssdOkNhQsMe67LyKAYKc9yLcc5IQd-oHus_BgPU6U24F8vZBdyfHbk9tMMocJu96hvANSHEaiUrSc7lB'),
#  Document(metadata={'source': 'data.txt'}, page_content='Ju96hvANSHEaiUrSc7lBit7qUKj8szoQufXCoIaEw1MPftVL0QJ_MMOhk6MKq?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='Windrow composting involves placing organic materials in **long, narrow rows** and periodically turning them.\n\nIt is one of the most widely used large-scale composting approaches. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Typical arrangement\n\n```text\n      Windrow\n   ________________\n  /                \\\n /                  \\\n/                    \\\n----------------------\n       Ground\n```'),
#  Document(metadata={'source': 'data.txt'}, page_content='The pile is periodically turned using:\n\n* Manual forks — small scale\n* Tractor/front loader\n* Mechanical windrow turner\n\n### Operations'),
#  Document(metadata={'source': 'data.txt'}, page_content='1. Waste collection\n2. Segregation\n3. Shredding\n4. Mixing\n5. Moisture adjustment\n6. Windrow formation\n7. Temperature monitoring\n8. Turning\n9. Cooling\n10. Curing\n11. Screening\n12. Quality testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='12. Quality testing\n13. Storage'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Advantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Simple technology.\n* Suitable for large quantities.\n* Lower capital cost than many enclosed systems.\n* Easy to expand.\n* Suitable for agricultural residues and municipal organic waste.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Mechanical turning improves aeration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Requires considerable land.\n* Weather dependent.\n* Possible odour problems.\n* Leachate management may be necessary.\n* Requires machinery for large-scale operations.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Greater exposure to rain and contamination.'),
#  Document(metadata={'source': 'data.txt'}, page_content='EPA notes that windrows can accommodate small to large volumes and a wide variety of materials, although equipment such as loaders or windrow turners may be required at larger scales. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 7. Static pile composting\n\nIn static pile composting, organic material is formed into a pile and **not routinely turned**.\n\nAir movement occurs naturally through the pile.\n\n### Principle'),
#  Document(metadata={'source': 'data.txt'}, page_content='Heat generated by microbial activity causes warm air to rise, while cooler air enters through lower portions of the pile. This is sometimes described as the **chimney effect**. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Advantages\n\n* Simple.\n* Low labour.\n* Low equipment requirement.\n* Suitable for smaller operations.\n\n### Disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Poor aeration can develop inside the pile.\n* Anaerobic zones may form.\n* Slower than well-managed forced-aeration systems.\n* More difficult to control temperature uniformly.\n* Odour can develop.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 8. Aerated Static Pile Composting — ASP'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/zaIJluD7KAanP7qYZd-q9UB2XRQp-ItEEWE_5TCNP-OGscoBFr3x1ezJ9s0oi0TBhtCb392tTiiwpdqj5MVnfHVE0DzEN6Zoht9mZecqrygTMiwFR3Voos38BFtu1yp0W1xg4DCPJwFfqrtofYef7pX'),
#  Document(metadata={'source': 'data.txt'}, page_content='g4DCPJwFfqrtofYef7pXTO-XUv50yNUD_rkAaXSxtGTmmEOy248-A27Cu55H9?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/e1nVCDjKYJRYOiZ7BuscKmlU1LUgd7SpRQdJ6s4sfrQO_CwhypOXFJe-Ipy_3LP9GXqtgPleMw74WPl4eHyT-pYvcBlsHlBQ8lh4-x6_xWH-2jUySW82Wn1XaYfv2h7xu5qGE2trHrVoIlnl4MIZuwI'),
#  Document(metadata={'source': 'data.txt'}, page_content='GE2trHrVoIlnl4MIZuwIPjuQWNKWDxRcym1go4WCbNclgPgKPiThp3ckYr6rS?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/U_WmfYYyWeZyYpNosKK82GnpOyWDAmSfUYiL_ptWE153q-tUknnJu06Y0pmuOTf4zmK43xI5k3FTrltg1Sdjfoj0MnJo83gqb9VsBMyQMWlk62OtmdnLFzze68knaj4J_aFEzEXFVLxcVtfsxAPey0y'),
#  Document(metadata={'source': 'data.txt'}, page_content='EzEXFVLxcVtfsxAPey0yROo4vrT09FxHOMNtmKP3ATZKnEoQ9H4BgbVK87jQF?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/JNPtK394i2G5smcztz45IOHoZez0neTZx0oPTMkkdNjPGclWwF3rkcZvClx7S0UtEKdtzpbrEQTHVMv2bKOTYCXILA7e-GP22sop_9Cuz5uHztGPPzhl8Rp34il5uZpAl3ZiSvVzN_u63Iu_OoOKw7u'),
#  Document(metadata={'source': 'data.txt'}, page_content='iSvVzN_u63Iu_OoOKw7u6HD0PcsyS3rJsNgAH_qyNFmaJQs9sVIzUEQT_YvJC?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/TRPVhWZlrX3ou1-Ra7GW25MmVdLi3N82Z9l2w3fFCmBadYHQI16R4Q63VIFi244WwSxAfiVpj39byDgJKxr-_C_mRR9Ln4sB6067nQqZ3qFSQAGneo6KBRjoP_BC-3javqMpyj8hVZImougo29VDJR_'),
#  Document(metadata={'source': 'data.txt'}, page_content='pyj8hVZImougo29VDJR_OW6NkwyEHp2gn5odO1pf-QfZP7otjUVMvauPceXSJ?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/2uZyxJZmZiYwlMQ96AGrfkkxNk32Wq0xNVgKAKcV8vK7irdt9LATPVNeJUxtkqwtqA8dk97WclEepcMLWD1v7FDxpcF1k7-gxyhVsahQY2lKDLMEfK15rQDB7XGOEzTpQj-xyQfQqcOU2Q3VFJ3XbOn'),
#  Document(metadata={'source': 'data.txt'}, page_content='xyQfQqcOU2Q3VFJ3XbOnWPm-Mmyl7ZpJgQO-ZL6UnzBf4S7CXZYeK-Hrkl_B_?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='This is an advanced version of static pile composting.\n\nPerforated pipes are placed under or inside the pile, and air is supplied using blowers.\n\n### Principle'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Principle\n\n**Blower → perforated pipes → compost pile → oxygen supply**\n\nThe blower can be controlled using:\n\n* Timer\n* Temperature sensor\n* Oxygen sensor\n* Automated control system'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Advantages\n\n* Better oxygen control.\n* Less turning required.\n* Suitable for large quantities.\n* Better control of odour in properly designed systems.\n* Can reduce labour requirements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages\n\n* Higher capital cost.\n* Requires blower and piping.\n* Requires electricity.\n* Improper airflow can dry the material.\n* Air distribution can be uneven.'),
#  Document(metadata={'source': 'data.txt'}, page_content='EPA describes aerated static piles as systems where active aeration can be provided through pipes beneath the pile, sometimes with blowers and odour-control arrangements. ([US EPA][3])\n\n---'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 9. In-vessel composting'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/QTtaKL-UqBygKsPxQo32CscvEMqPDKRkBgzMhyVpZ8E5LerfZXkgMJ9YwyEj9athvFrEAq-GKdiGJRVQRtrzyXJL11m89umrrGgSx1agOAMo12kOdz3eiWxT0y5wNGauCjglOarWPb2x242x6dSeRys'),
#  Document(metadata={'source': 'data.txt'}, page_content='lOarWPb2x242x6dSeRyswTDo5I3TE45bjsJBmIabZEJniD7mbavsF9vIJfsGU?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/cZU-5yoi71qFz0S3YryQLBA43kM4s4bBbTHdsm6qaBR7Sp5Jw1SL7THXfumsDI35BaObJUdYWYGfO_BCqvclfr1SeUoTp2tOypt8yEbVpgQmT3nKWzvAq59CCmQ4rdUNLU-PTu7jUzArQqQBCXVs4q-'),
#  Document(metadata={'source': 'data.txt'}, page_content='PTu7jUzArQqQBCXVs4q-pGPUlmVVZ0ejnUJYE7-RGYXBglAZRDU68bFL8is8u?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/2HZqEYKkrSqubHFLUp9QNjzxvBx18puKp3C7CIL9L_LNvTaGxqQ0qODtf17U2CPE1NzC6DQnSYvTRUgd6H8PR3x3o0IAz9SDMKxXBiI1i4agz2ZorHKylpoahfhfK8PB9NgObyfD5mBexpT0T81Ntk3'),
#  Document(metadata={'source': 'data.txt'}, page_content='ObyfD5mBexpT0T81Ntk3t1pv3iVC5iTSqjdApF-Ze8pD-3FbTZkV2jpKt6yyO?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/8_xfm_6vUaPUG_iqnP-G6V5HjCxCsR9vzMd-q6eYJBnpjQTSFTNXhghCtR2gAHQ3JRDCVAa2RDgTkiOhoWj6jiLo0oIDAW9gTVNK-dZMeIOenpzTNdZhqRJtoapVtXvWbG-rhDjVvJDoJVas5VWJwkm'),
#  Document(metadata={'source': 'data.txt'}, page_content='rhDjVvJDoJVas5VWJwkmqLp5M2Gv4mEQlrYzad5oU2q74CuzbIzjRG9BIZBxM?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/S5Oy9t1j91jKfBZV68cTX1RPlud1hu56i0FFF84pRlsRVQZtimXTJ9pgy1OAZcGzFy7DnjKnbVlSugjbPe06lW5HboEBKLcyCTWz45B0ucgpA2oQNB390q4LbvXgPCqxz4u_AvK_zZSyOZGBGOhkEk6'),
#  Document(metadata={'source': 'data.txt'}, page_content='_AvK_zZSyOZGBGOhkEk6sdEg6w2kAB3_ww3UwCUaVdNRXvTeCT8ygOUJmTT5b?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/8pIvx_Kvz2VuYx0Rn9_wXpXFi5QNTbD4Rs2tYR2aLPLXS5Myl2WA7apOYvUZAfvwQo9mRwdxx2SzJTuofqsFTMJ-3YWDskrXg7iH-_zQ4Oe6fAURzZ33XMMW3gqf83ylHeg7sHiupoP-qU5fb2e8yva'),
#  Document(metadata={'source': 'data.txt'}, page_content='7sHiupoP-qU5fb2e8yva4l7TmKOwPpglP7PDzpLMFxMYxYsqnGumBhiJuqQHA?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='In-vessel composting occurs inside an enclosed structure such as:\n\n* Rotating drum\n* Composting reactor\n* Concrete-lined vessel\n* Silo\n* Enclosed channel\n* Agitated bay'),
#  Document(metadata={'source': 'data.txt'}, page_content='The material is mechanically mixed and aerated.\n\n### Advantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Requires less land.\n* Excellent process control.\n* Faster processing.\n* Temperature can be closely monitored.\n* Suitable for urban areas.\n* Better containment of odour and process conditions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Can handle many feedstock types.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages\n\n* High capital cost.\n* Requires electricity.\n* Mechanical maintenance is required.\n* Skilled operation may be required.\n* Final material may still require curing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='EPA identifies in-vessel systems as enclosed systems where materials are mechanically turned or mixed and aerated; they can process diverse materials while requiring less space than open systems.'),
#  Document(metadata={'source': 'data.txt'}, page_content='than open systems. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 10. Vermicomposting'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/8Aelz9S5Xw3tPaJU7cABBtMNR1T_SkpBDL6QrsIY3gaTOxHSNzClx5tMTgixM3y_ywSyp6D4ymzY51wt9zowoPPx5trrMyzosxbubPIujzizoK5rzyZ_qvQYBp7uM4JoIFbw3bHTHiY7C4NhEfmIcZ5'),
#  Document(metadata={'source': 'data.txt'}, page_content='w3bHTHiY7C4NhEfmIcZ5_kTqMqJ9Y3hN1jXsDKRPnVNtFi_xH00GuRQHTrbLS?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/lwzB_eO4eJZKPIUgt8sIsdA16CvydIgusEksc6oNLDr3jiAreA1Ni9Vf_wjsy3xqDfdKUCo-ciQ4jLS-wfzKabqAPdBN_Mtb4L6N3wM4ehI_HBH-eWqJHfxNCROO_Q3ShIPf6Nlz_u48dBydjlkiDsx'),
#  Document(metadata={'source': 'data.txt'}, page_content='f6Nlz_u48dBydjlkiDsxm8Ue__HXGZIPz8rjt9uN9bS8RigkXSTxdQbrUZ72b?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/1l8sBmyBedwcL71koy_FVxvfvblX-cCEZZxfZ--rtX6bzQg3rRkR5z7dSU4rzeXOfmq7ythhOqT06bFFU2l8jyq8Gyf95flI8-vpX09SjNFqZHORI9fzKn1UtWiShaTe9Fw0ppqaQ0-nn3wgw78_c8-'),
#  Document(metadata={'source': 'data.txt'}, page_content='0ppqaQ0-nn3wgw78_c8-nnDYjzDJXpQujeQ7VbMxtxRLjW9AbogqCQb1cCRZ7?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/ZIox36WuBYgo-WjyG8K5763E3uCTb15WgLfDKr8cBTK8otoB-JF2cLZpd3EX5dbGpleLPSqTg4k5r97gXfnuW7bFYLDJLE7KJ7gOVpj_sTyBxZC7F70ThurW3mxnj6JVsDZRbZE0Kz8H1cjc0JBq-Az'),
#  Document(metadata={'source': 'data.txt'}, page_content='RbZE0Kz8H1cjc0JBq-AzLLDckUt8hB6Ml3qu_O6vZx9kL4eqLF76cdVlu_9ll?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/HjJLT7OTnPDaOd_FD_WK3aigM8V4PWPYVRoElcxf-8JM_0ex_25qoDpWJHBQTTkaJxov7SLvUSUne2gA2UO2AKL6T58jcbgTH4HjnRu7syglmtxuj8m3lo9xGPokQMX44E5VT819DAghMGeyQJNQrYO'),
#  Document(metadata={'source': 'data.txt'}, page_content='VT819DAghMGeyQJNQrYOdDTrJGP1r2m1AEg1ug-3uj4KqnOEYxQpAVE_Elsrm?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/FVtB-CspCGQUfyqFhXSaDBbMO-D2qgAOLvYeBlYx5cDz_2fRC-Z7RFyBi4HxhrkRDn7mQgWDANN8Al4PGulWMBQ-9Cy8wcXGqDQ0K4NUUR3cUaNik0JeMVnW8YcrAaiFIJGKRloJRltRcpDQNxG8ik3'),
#  Document(metadata={'source': 'data.txt'}, page_content='KRloJRltRcpDQNxG8ik3UNU6ErRjVaiVsrj_IK6vTmRaaW1-cg6dX-L2iJm-F?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/CQs7-YbqmrJmyrmAZmUop4ZyJAZe6PTcRBnlfxxA-OnePSsFV5V-ENef-L6GXckMt2zsA_KE1gyaA1ibn1L6vcnfqhUq-Q-RpslpsrgWQvzfy7XAfEM6r2nFpcD2_IRqm-tbn3E3Q9Vpz3MrQwXeh_t'),
#  Document(metadata={'source': 'data.txt'}, page_content='bn3E3Q9Vpz3MrQwXeh_threBfr9kPgys3u-PI3EO-RQzZamr79Tp-GiKO_haa?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='![Image](https://images.openai.com/static-rsc-4/IEaHs1xSpcn1e3J-vfljc8P2O3hkxobkspbW8zIR1Ygi9w3gBKMHLfUn92XC4wvwbDAzMcgJdOTmA4e6WDeUi1IubFfu7EkS9zgmK4404YdQntIRe-VUDdZUlg2Bc7np2B3A96Q3jnmAtY1e5Bn63kG'),
#  Document(metadata={'source': 'data.txt'}, page_content='A96Q3jnmAtY1e5Bn63kGQtTp9hgRPH6j20rxau_5tt76ShRoBzEzE1hgnYyFZ?purpose=fullsize)'),
#  Document(metadata={'source': 'data.txt'}, page_content='Vermicomposting uses **earthworms + microorganisms** to process organic material.\n\nA commonly used species is **Eisenia fetida**, often called the red wiggler.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The worms consume partially decomposed organic matter and produce **vermicast/vermicompost**. ([US EPA][4])\n\n### Important point'),
#  Document(metadata={'source': 'data.txt'}, page_content='Vermicomposting is **not simply conventional thermophilic composting with worms added from the beginning**.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Earthworms are sensitive to high temperatures. Therefore, fresh material can first undergo partial decomposition/cooling before worms are introduced.\n\n### Suitable materials'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Cow dung\n* Vegetable waste\n* Fruit waste\n* Crop residues\n* Leaf litter\n* Partially decomposed organic waste\n* Paper/cardboard in suitable proportions\n\n### Advantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* High-quality soil amendment.\n* Low-energy process.\n* Can be operated at small scale.\n* Requires relatively little space.\n* Produces worm castings.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Good option for household/institutional organic waste.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Worms are sensitive to temperature.\n* Sensitive to excessive moisture.\n* Sensitive to toxic/contaminated materials.\n* Cannot tolerate fresh thermophilic compost conditions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Requires regular management.\n* Production rate can be lower than high-throughput mechanical systems.'),
#  Document(metadata={'source': 'data.txt'}, page_content='EPA notes that vermicomposting can be performed indoors or outdoors and requires appropriate worms, bedding, airflow and drainage. ([US EPA][4])\n\n---\n\n# 11. Passive/home composting'),
#  Document(metadata={'source': 'data.txt'}, page_content='This is the simplest form.\n\nExamples:\n\n* Backyard compost pile\n* Compost bin\n* Household composting\n* Community composting'),
#  Document(metadata={'source': 'data.txt'}, page_content='Materials are periodically mixed or left to decompose with limited intervention.\n\n### Advantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Advantages\n\n* Very low cost.\n* Simple.\n* No sophisticated machinery.\n* Suitable for household food and garden waste.\n\n### Disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Disadvantages\n\n* Slow.\n* Poor process control.\n* Variable temperature.\n* Quality can vary.\n* Potential odour/pest problems if poorly managed.\n\n---\n\n# 12. Comparison of composting methods'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Method              | Scale        | Aeration          | Cost          | Speed         | Land requirement | Main advantage            |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| ------------------- | ------------ | ----------------- | ------------- | ------------- | ---------------- | ------------------------- |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Home/passive        | Small        | Natural           | Very low      | Slow          | Low–moderate     | Simple                    |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Static pile         | Small–medium | Natural           | Low           | Moderate      | Moderate         | Low labour                |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Windrow             | Medium–large | Turning           | Moderate      | Moderate-fast | High             | Large volume              |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Aerated static pile | Medium–large | Forced            | Moderate-high | Fast          | Moderate         | Better control            |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| In-vessel           | Medium–large | Mechanical/forced | High          | Fast          | Low              | Excellent control         |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Vermicomposting     | Small–medium | Natural           | Low–moderate  | Moderate      | Low              | High-quality vermicompost |'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 13. Sources of raw materials for composting\n\nThis is particularly important for **your project**.\n\nOrganic materials can broadly be divided into:\n\n### A. Agricultural waste\n\nExamples:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Examples:\n\n* Wheat husk\n* Rice straw\n* Paddy husk\n* Maize stalk\n* Corn husk\n* Sugarcane bagasse\n* Cotton residues\n* Groundnut shells\n* Soybean residues\n* Vegetable crop residues\n* Fruit residues'),
#  Document(metadata={'source': 'data.txt'}, page_content='### B. Animal waste\n\nExamples:\n\n* Cow dung\n* Buffalo dung\n* Horse manure\n* Goat manure\n* Sheep manure\n* Poultry litter\n\nAnimal manure is generally nitrogen-rich compared with many dry crop residues.'),
#  Document(metadata={'source': 'data.txt'}, page_content='### C. Kitchen/food waste\n\nExamples:\n\n* Vegetable peels\n* Fruit peels\n* Food scraps\n* Tea waste\n* Coffee grounds\n* Leftover plant-based food\n\n### D. Garden/landscape waste\n\nExamples:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Examples:\n\n* Grass clippings\n* Dry leaves\n* Small branches\n* Flowers\n* Hedge trimmings\n* Weeds\n\n### E. Industrial organic waste\n\nDepending on contamination and regulatory requirements:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Sugar industry residues\n* Food-processing residues\n* Brewery residues\n* Fruit-processing waste\n* Agricultural processing residues\n* Paper-processing residues\n\n### F. Municipal organic waste'),
#  Document(metadata={'source': 'data.txt'}, page_content='Properly segregated:\n\n* Food waste\n* Garden waste\n* Market waste\n* Vegetable market residues'),
#  Document(metadata={'source': 'data.txt'}, page_content='Contaminated mixed municipal waste is **not automatically suitable** for composting. Feedstock segregation is essential.\n\n---\n\n# 14. Raw materials according to their function'),
#  Document(metadata={'source': 'data.txt'}, page_content='For your project, this classification is very useful.'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Function                 | Examples                                                            |\n| ------------------------ | ------------------------------------------------------------------- |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Carbon source            | Wheat husk, straw, dry leaves, sawdust                              |\n| Nitrogen source          | Cow dung, poultry manure, green leaves                              |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Moisture source          | Water, wet vegetable waste                                          |\n| Easily degradable carbon | Fruit/vegetable waste, jaggery-containing solution                  |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Phosphorus source        | Manure, some food/agricultural residues, approved phosphate sources |\n| Potassium source         | Vegetable/fruit residues, plant ash where appropriate               |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Bulking agent            | Wood chips, straw, dry leaves                                       |\n| Microbial inoculant      | Decomposer, N-fixing, P-solubilizing, K-solubilizing cultures       |'),
#  Document(metadata={'source': 'data.txt'}, page_content="---\n\n# 15. Raw materials suitable for YOUR project\n\nBased on the project you've been developing, your system can be structured as:\n\n### Carbon-rich component\n\n**Wheat husk**\n\nPurpose:"),
#  Document(metadata={'source': 'data.txt'}, page_content='Purpose:\n\n* Carbon source\n* Structural material\n* Improves porosity\n* Provides lignocellulosic substrate\n\n### Nitrogen/microbial component\n\n**Cow dung**\n\nPurpose:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Purpose:\n\n* Nitrogen source\n* Naturally rich microbial population\n* Helps initiate decomposition\n* Helps balance high-carbon agricultural residues\n\n### Nutrient supplements\n\nYou have considered:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* NPK\n* Pumpkin + jaggery + water\n* Bael + jaggery + water\n\nThese should be treated as **experimental supplements**, not assumed to improve all nutrients automatically.\n\n### Microbial augmentation'),
#  Document(metadata={'source': 'data.txt'}, page_content='Your proposed inoculants include functional groups such as:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Nitrogen-fixing microorganisms\n* Phosphate-solubilizing microorganisms\n* Potassium-solubilizing microorganisms\n* Decomposer cultures\n* Actinomycetes'),
#  Document(metadata={'source': 'data.txt'}, page_content='This gives you a very good experimental comparison.\n\n---\n\n# 16. What operations are performed during composting?\n\nA composting facility can be divided into:\n\n## Stage 1 — Collection'),
#  Document(metadata={'source': 'data.txt'}, page_content='Organic waste is collected from:\n\n* Agriculture\n* Farms\n* Markets\n* Kitchens\n* Municipal sources\n* Animal facilities\n\n---\n\n## Stage 2 — Segregation\n\nRemove:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Remove:\n\n* Plastic\n* Glass\n* Metal\n* Stones\n* Rubber\n* Chemical-contaminated materials\n\nThis is extremely important for final compost quality.\n\n---\n\n## Stage 3 — Size reduction\n\nMaterials can be:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Materials can be:\n\n* Chopped\n* Shredded\n* Ground\n* Cut'),
#  Document(metadata={'source': 'data.txt'}, page_content='Smaller particles generally provide greater surface area for microorganisms, but **overly fine material can reduce porosity and restrict airflow**. ([US EPA][5])\n\n---\n\n## Stage 4 — Mixing\n\nMix:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Mix:\n\n**Carbon-rich material + nitrogen-rich material + moisture + optional inoculants**\n\nFor example:\n\n**Wheat husk + cow dung + water**\n\nor your experimental:'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Wheat husk + cow dung + nutrient supplements + microbial inoculants**\n\n---\n\n# 17. Moisture adjustment\n\nMoisture is one of the most important operating parameters.\n\nToo little moisture:'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Microbial activity ↓ → decomposition ↓**\n\nToo much moisture:\n\n**Air spaces ↓ → oxygen ↓ → anaerobic conditions → odour**'),
#  Document(metadata={'source': 'data.txt'}, page_content='A commonly used practical target for active aerobic composting is around **50–60% moisture**, although the ideal value depends on feedstock and system. ([US EPA][2])\n\n---\n\n# 18. Turning'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 18. Turning\n\nTurning performs several functions:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Introduces oxygen.\n* Mixes fresh and partially decomposed material.\n* Equalizes temperature.\n* Redistributes moisture.\n* Prevents anaerobic pockets.\n* Helps uniform decomposition.'),
#  Document(metadata={'source': 'data.txt'}, page_content='For a small academic experiment, you could maintain a fixed turning schedule, for example:\n\n**Day 0 → Day 7 → Day 14 → Day 21 → Day 28 → thereafter as required**'),
#  Document(metadata={'source': 'data.txt'}, page_content='But scientifically, temperature and moisture should also be considered rather than blindly turning on a fixed schedule.\n\n---\n\n# 19. Temperature monitoring'),
#  Document(metadata={'source': 'data.txt'}, page_content='Temperature is one of the **most important composting indicators**.\n\nTypical pattern:'),
#  Document(metadata={'source': 'data.txt'}, page_content='```text\nTemperature\n    │\n70°C│\n    │              ______\n60°C│            /        \\\n    │           /          \\\n50°C│         /              \\\n    │       /                 \\\n40°C│     /'),
#  Document(metadata={'source': 'data.txt'}, page_content='40°C│     /\n    │   /\n30°C│__/\n    └──────────────────────────── Time\n       Mesophilic Thermophilic Cooling Maturation\n```'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Interpretation\n\n**Initial stage**\n\nMicroorganisms become active.\n\n**Thermophilic stage**\n\nRapid degradation occurs.\n\n**Cooling stage**\n\nEasily degradable substrates decline.\n\n**Maturation**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Maturation**\n\nSlow decomposition and stabilization occur.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Temperature monitoring is also important because excessively high temperatures can suppress beneficial microorganisms, while insufficient heating may indicate poor microbial activity or'),
#  Document(metadata={'source': 'data.txt'}, page_content='activity or insufficiently balanced feedstock. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 20. Testing of compost\n\nThis is the most important part for your **M.Tech/UG environmental engineering research**.\n\nTesting can be divided into:\n\n### A. Physical tests\n\n### B. Chemical tests'),
#  Document(metadata={'source': 'data.txt'}, page_content='### C. Biological/maturity tests\n\n### D. Microbiological tests\n\n### E. Contaminant/safety tests\n\n---\n\n# 21. Physical testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Test          | What it tells you                 |\n| ------------- | --------------------------------- |\n| Moisture      | Water content                     |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Bulk density  | Physical quality/handling         |\n| Particle size | Degree of screening/decomposition |\n| Colour        | Maturity indication               |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Odour         | Anaerobic activity/immaturity     |\n| Texture       | Physical stability                |\n| Temperature   | Biological activity               |'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Moisture\n\nCan be determined by:\n\n**Oven drying method**\n\nSample → Weigh → Oven dry → Cool → Weigh → Calculate moisture.\n\n---\n\n# 22. Chemical testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='These are particularly important for your project.\n\n### 1. pH\n\nIndicates acidity/alkalinity.\n\nUsually measured using:\n\n**pH meter**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**pH meter**\n\nCompost often shifts toward neutral/mildly alkaline conditions during stabilization.\n\n---\n\n### 2. Electrical conductivity — EC\n\nIndicates soluble salts.\n\nHigh EC can indicate:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Excess salts\n* Excessive nutrient supplementation\n* Potential phytotoxicity\n\n---\n\n### 3. Organic carbon\n\nOrganic carbon indicates the carbonaceous fraction.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Common approaches include laboratory oxidation methods or instrument-based carbon analysis.\n\n---\n\n### 4. Total nitrogen\n\nFor your project, **Kjeldahl nitrogen** is highly relevant.\n\nBasic sequence:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Basic sequence:\n\n**Digestion → Distillation → Titration → Total Kjeldahl Nitrogen**\n\nIt is particularly useful for comparing:\n\n* Control compost\n* Cow-dung compost\n* Microbial-augmented compost\n\n---'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 23. C:N ratio\n\nThis is one of the most important composting parameters.\n\n[\nC:N=\\frac{\\text{Total Organic Carbon}}{\\text{Total Nitrogen}}\n]\n\nExample:\n\nIf:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Example:\n\nIf:\n\n* Organic carbon = 30%\n* Total nitrogen = 1.5%\n\nThen:\n\n[\nC:N = 30/1.5 = 20:1\n]'),
#  Document(metadata={'source': 'data.txt'}, page_content='A declining C:N ratio generally indicates decomposition of carbon-rich material and progression toward stabilization.\n\nHowever, **C:N alone should not be used as the only maturity indicator**.\n\n---'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 24. Phosphorus testing\n\nPhosphorus can be determined using appropriate extraction followed by:\n\n* Spectrophotometry\n* Colorimetric methods\n\nFor your project, you can investigate:\n\n**Total P**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Total P**\n\nand/or\n\n**Available P**\n\nThis distinction is important.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Your microbial augmentation may affect **phosphorus solubilization**, so measuring only total P may not capture the complete biological effect.\n\n---\n\n# 25. Potassium testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='Potassium is commonly measured using:\n\n* Flame photometer\n* Atomic absorption spectroscopy\n* ICP-OES/ICP-MS where available'),
#  Document(metadata={'source': 'data.txt'}, page_content='For a university laboratory, **flame photometry** can be a practical method.\n\nMeasure:\n\n**Total/extractable K**, depending on the selected standard method.\n\n---\n\n# 26. Biological testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='Biological tests are very useful for determining whether compost is actually mature.\n\n### Germination Index — GI\n\nA compost extract is applied to seeds and compared with a control.\n\nIt can assess:'),
#  Document(metadata={'source': 'data.txt'}, page_content='It can assess:\n\n* Phytotoxicity\n* Compost maturity\n* Plant compatibility\n\nA high germination index generally indicates lower phytotoxicity.\n\n---\n\n# 27. Respiration testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='Respiration tests measure biological activity through:\n\n* Oxygen consumption\n* CO₂ evolution\n\nImmature compost generally has higher microbial respiration.\n\nAs compost stabilizes:\n\n**Respiration ↓**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Respiration ↓**\n\nThis provides a useful maturity/stability indicator.\n\n---\n\n# 28. Microbiological testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='For your microbial augmentation project, microbiological testing can become particularly valuable.\n\nPossible analyses include:\n\n### Total viable microbial count'),
#  Document(metadata={'source': 'data.txt'}, page_content='Measures culturable microbial population.\n\n### Functional microbial groups\n\nDepending on laboratory facilities:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Nitrogen-fixing bacteria\n* Phosphate-solubilizing bacteria\n* Potassium-solubilizing microorganisms\n* Cellulolytic microorganisms\n* Actinomycetes\n\n### Pathogen testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='Depending on intended use and applicable standards:\n\n* Total coliforms\n* Fecal/E. coli indicators\n* Salmonella\n* Other relevant pathogens'),
#  Document(metadata={'source': 'data.txt'}, page_content='Thermophilic composting is important for pathogen reduction. ([US EPA][2])\n\n---\n\n# 29. Advanced testing\n\nIf you want to make the project more research-oriented, you can add:\n\n### FTIR'),
#  Document(metadata={'source': 'data.txt'}, page_content='### FTIR\n\nUsed to observe changes in functional groups.\n\nCan indicate changes in:\n\n* Cellulose\n* Hemicellulose\n* Lignin\n* Carboxyl groups\n* Hydroxyl groups\n\n### SEM'),
#  Document(metadata={'source': 'data.txt'}, page_content='### SEM\n\nScanning Electron Microscopy can show:\n\n* Surface morphology\n* Degradation of plant fibres\n* Structural changes\n\n### XRD'),
#  Document(metadata={'source': 'data.txt'}, page_content='### XRD\n\nCan investigate crystalline/amorphous changes in mineral/organic components where appropriate.\n\n### TGA/DSC\n\nCan assess thermal stability and decomposition characteristics.\n\n### UV-Vis'),
#  Document(metadata={'source': 'data.txt'}, page_content='### UV-Vis\n\nCan be used for certain dissolved organic matter or nutrient assays depending on the method.\n\n---\n\n# 30. What should YOU test in your project?'),
#  Document(metadata={'source': 'data.txt'}, page_content='For your specific project, I would divide the testing into **three levels**.\n\n### Level 1 — Essential'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Parameter      | Initial | During composting | Final |\n| -------------- | ------: | ----------------: | ----: |\n| Temperature    |       ✓ |                 ✓ |     ✓ |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Moisture       |       ✓ |                 ✓ |     ✓ |\n| pH             |       ✓ |                 ✓ |     ✓ |\n| Organic carbon |       ✓ |                 — |     ✓ |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Total N        |       ✓ |          Optional |     ✓ |\n| P              |       ✓ |          Optional |     ✓ |\n| K              |       ✓ |          Optional |     ✓ |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| C:N            |       ✓ |                 ✓ |     ✓ |\n| Final mass     |       ✓ |                 — |     ✓ |'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Level 2 — Strongly recommended\n\n* Electrical conductivity\n* Germination index\n* Organic matter\n* Bulk density\n* Respiration/stability\n* Microbial count\n\n### Level 3 — Advanced research'),
#  Document(metadata={'source': 'data.txt'}, page_content='* FTIR\n* SEM\n* Functional microbial enumeration\n* Enzyme activity\n* Molecular microbial analysis\n* Statistical modelling\n\n---\n\n# 31. Different composting methods require different monitoring'),
#  Document(metadata={'source': 'data.txt'}, page_content='This is an important distinction.'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Composting method             | Most important operational monitoring                   |\n| ----------------------------- | ------------------------------------------------------- |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Windrow                       | Temperature, moisture, turning, oxygen                  |\n| Static pile                   | Temperature, moisture, aeration                         |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Aerated static pile           | Temperature, oxygen/airflow, moisture, blower operation |\n| In-vessel                     | Temperature, airflow, mixing speed, moisture            |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Vermicomposting               | Temperature, moisture, pH, worm health, feed rate       |\n| Home composting               | Moisture, odour, temperature, feedstock balance         |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Manure composting             | Temperature, moisture, N, odour, pathogens              |\n| Food-waste composting         | Moisture, C:N, odour, temperature, EC                   |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Agricultural-waste composting | C:N, moisture, temperature, lignocellulose degradation  |'),
#  Document(metadata={'source': 'data.txt'}, page_content="---\n\n# 32. Very important: composting vs vermicomposting\n\nDon't combine these two processes incorrectly in your project.\n\n### Conventional aerobic composting\n\nMain biological agents:"),
#  Document(metadata={'source': 'data.txt'}, page_content='**Bacteria + fungi + actinomycetes**\n\nHigh-temperature phase:\n\n**Yes**\n\nTypical objective:\n\n**Rapid decomposition + stabilization + pathogen reduction**\n\n### Vermicomposting\n\nMain agents:'),
#  Document(metadata={'source': 'data.txt'}, page_content='Main agents:\n\n**Earthworms + microorganisms**\n\nHigh-temperature thermophilic phase:\n\n**Not suitable for active worm beds**\n\nTypical objective:\n\n**Production of vermicompost/worm castings**'),
#  Document(metadata={'source': 'data.txt'}, page_content='Therefore, if your project is specifically about **microbial augmentation**, conventional aerobic composting is actually a very suitable experimental platform because you can compare microbial'),
#  Document(metadata={'source': 'data.txt'}, page_content='compare microbial inoculation against a control while monitoring temperature, C:N, N, P and K.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 33. How your project can be structured\n\nYour research can become much stronger if you use a **control + treatment approach**.\n\n### Treatment 1 — Control\n\n**Wheat husk**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Wheat husk**\n\n### Treatment 2 — Conventional compost\n\n**Wheat husk + cow dung**\n\n### Treatment 3 — Nutrient supplemented\n\n**Wheat husk + cow dung + nutrient supplements**'),
#  Document(metadata={'source': 'data.txt'}, page_content='### Treatment 4 — Microbial augmented\n\n**Wheat husk + cow dung + microbial inoculants**\n\n### Treatment 5 — Integrated treatment'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Wheat husk + cow dung + nutrient supplements + microbial inoculants**'),
#  Document(metadata={'source': 'data.txt'}, page_content='This fifth treatment could be particularly interesting because it allows you to determine whether **nutrient supplementation and microbial augmentation have an interaction** rather than simply'),
#  Document(metadata={'source': 'data.txt'}, page_content='rather than simply comparing "with microbes" and "without microbes."'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 34. Your experimental flow'),
#  Document(metadata={'source': 'data.txt'}, page_content='```text\nAgricultural waste\n       ↓\n   Segregation\n       ↓\n Size reduction\n       ↓\nCharacterization\n       ↓\nC, N, P, K, moisture, pH\n       ↓\n    Mixing\n       ↓\n ┌───────────────┐'),
#  Document(metadata={'source': 'data.txt'}, page_content='┌───────────────┐\n │ Experimental  │\n │ treatments    │\n └───────────────┘\n       ↓\nMoisture adjustment\n       ↓\nMicrobial inoculation\n       ↓\nComposting\n       ↓\nTemperature monitoring\n       ↓'),
#  Document(metadata={'source': 'data.txt'}, page_content='↓\nTurning / aeration\n       ↓\nMoisture monitoring\n       ↓\nCooling\n       ↓\nCuring\n       ↓\nScreening\n       ↓\nFinal testing\n       ↓\nN – P – K – C:N – pH – EC\n       ↓\nMaturity testing'),
#  Document(metadata={'source': 'data.txt'}, page_content='Maturity testing\n       ↓\nStatistical comparison\n       ↓\nNutrient efficiency assessment\n```'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 35. The most important distinction for your research\n\nDon\'t define success simply as:\n\n> **"Treatment 3 has higher NPK than Treatment 1."**\n\nA much stronger scientific question is:'),
#  Document(metadata={'source': 'data.txt'}, page_content='> **"Does microbial augmentation increase nutrient retention and/or nutrient availability during the composting process while improving decomposition and compost maturity?"**'),
#  Document(metadata={'source': 'data.txt'}, page_content='That means you should consider both **concentration and mass retention**.\n\nFor example, suppose the initial material has:\n\n**100 kg dry matter × 2% N = 2 kg N**\n\nAfter decomposition:'),
#  Document(metadata={'source': 'data.txt'}, page_content='**50 kg dry matter × 3% N = 1.5 kg N**\n\nThe final N concentration increased from 2% to 3%, but the total N inventory decreased from 2 kg to 1.5 kg.\n\nSo:'),
#  Document(metadata={'source': 'data.txt'}, page_content='So:\n\n**Higher N concentration ≠ necessarily higher N retention.**\n\nThis is a very important point that can make your project scientifically stronger.\n\n---'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n# 36. Recommended testing matrix for your project'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Parameter         | Why measure it?           | Recommended method            |\n| ----------------- | ------------------------- | ----------------------------- |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Temperature       | Composting phase/activity | Compost thermometer           |\n| Moisture          | Microbial activity        | Oven drying                   |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| pH                | Stabilization             | pH meter                      |\n| EC                | Salt concentration        | Conductivity meter            |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Organic C         | Carbon degradation        | Standard laboratory method    |\n| Total N           | Nitrogen enrichment       | Kjeldahl                      |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| P                 | Phosphorus enrichment     | Spectrophotometric            |\n| K                 | Potassium enrichment      | Flame photometer              |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| C:N               | Maturity/decomposition    | Calculated                    |\n| Mass loss         | Decomposition             | Weighing                      |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| Germination index | Phytotoxicity/maturity    | Seed germination              |\n| Microbial count   | Inoculation effect        | Plate count/appropriate assay |'),
#  Document(metadata={'source': 'data.txt'}, page_content='| FTIR              | Functional-group changes  | FTIR                          |\n| SEM               | Structural degradation    | SEM                           |'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n## 37. Overall advantages of composting\n\n**Environmental**\n\n* Waste diversion\n* Nutrient recycling\n* Reduced landfill burden\n* Soil organic matter improvement\n* Circular economy'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Agricultural**\n\n* Soil conditioning\n* Nutrient supply\n* Improved water retention\n* Improved soil structure\n\n**Economic**'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Economic**\n\n* Low-cost feedstock\n* Converts waste into a usable product\n* Potential compost production enterprise\n\n**Research**\n\n* Excellent platform for studying:'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Microbial ecology\n  * Nutrient cycling\n  * Waste valorization\n  * Process optimization\n  * N-P-K recovery\n  * Biological enhancement\n\n---\n\n## 38. Overall disadvantages'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Requires land for open systems.\n* Requires labour and monitoring.\n* Improper aeration can cause odour.\n* Excess moisture can produce anaerobic conditions.\n* Nitrogen losses are possible.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Compost quality depends strongly on feedstock.\n* Contaminated feedstocks can contaminate the final product.\n* In-vessel systems have higher capital and energy requirements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='* Vermicomposting is sensitive to temperature and environmental conditions.\n* Composting does not eliminate every contaminant; feedstock quality remains critical.'),
#  Document(metadata={'source': 'data.txt'}, page_content='---\n\n### For your project, I would recommend this approach'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Primary process:** Aerobic composting\n**Method:** Small-scale controlled/static or mini-windrow system\n**Feedstock:** Wheat husk + cow dung\n**Experimental factor:** Microbial augmentation'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Additional factor:** Nutrient supplementation\n**Duration:** ~60 days\n**Main parameters:** Temperature, moisture, pH, EC, organic C, N, P, K and C:N'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Maturity:** Germination index + temperature stabilization + C:N + visual/odour observations\n**Advanced characterization:** FTIR/SEM if facilities are available'),
#  Document(metadata={'source': 'data.txt'}, page_content='**Analysis:** ANOVA + nutrient-retention/mass-balance analysis'),
#  Document(metadata={'source': 'data.txt'}, page_content='This gives you a much stronger foundation for the title **“Enhancement of Nutrient Efficiency of Compost Through Microbial Augmentation”** than simply producing compost and testing NPK at the end.'),
#  Document(metadata={'source': 'data.txt'}, page_content='NPK at the end. EPA similarly emphasizes that feedstock balance, particle size, oxygen, moisture and temperature are fundamental process controls across composting systems. ([US EPA][2])'),
#  Document(metadata={'source': 'data.txt'}, page_content='[EPA — Approaches to Composting](https://www.epa.gov/sustainable-management-food/approaches-composting?utm_source=chatgpt.com)'),
#  Document(metadata={'source': 'data.txt'}, page_content='[EPA — Composting Basics](https://www.epa.gov/sustainable-management-food/composting?utm_source=chatgpt.com)'),
#  Document(metadata={'source': 'data.txt'}, page_content='[1]: https://www.epa.gov/sustainable-management-food/composting?utm_source=chatgpt.com "Composting | US EPA"'),
#  Document(metadata={'source': 'data.txt'}, page_content='[2]: https://www.epa.gov/sustainable-management-food/approaches-composting?utm_source=chatgpt.com "Approaches to Composting | US EPA"'),
#  Document(metadata={'source': 'data.txt'}, page_content='[3]: https://www.epa.gov/system/files/documents/2025-01/environmental-value-of-applying-compost.pdf?utm_source=chatgpt.com "Environmental Value of"'),
#  Document(metadata={'source': 'data.txt'}, page_content='[4]: https://www.epa.gov/recycle/composting-home?utm_source=chatgpt.com "Composting At Home | US EPA"'),
#  Document(metadata={'source': 'data.txt'}, page_content='[5]: https://19january2021snapshot.epa.gov/sustainable-management-food/types-composting-and-understanding-process_.html?utm_source=chatgpt.com "Types of Composting and Understanding the Process |'),
#  Document(metadata={'source': 'data.txt'}, page_content='the Process | Sustainable Management of Food | US EPA"')]

# %%
texts = [doc.page_content for doc in finalDocuments]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
pip install langchain_huggingface
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.4.9)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.10.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.5.0)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.2

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.15.0-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)
# Downloading faiss_cpu-1.15.0-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 82.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.15.0

# %%
query = input("Enter your question : ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# Enter your question : Advantages of composting?
# # 1. What is composting?
# ---
#
# # 2. Why do we need composting?
#
# Composting provides several environmental and agricultural benefits.
#
# ### Environmental benefits
# ---
#
# ## 37. Overall advantages of composting
#
# **Environmental**
#
# * Waste diversion
# * Nutrient recycling
# * Reduced landfill burden
# * Soil organic matter improvement
# * Circular economy
# ### Disadvantages
#
# * Slow.
# * Poor process control.
# * Variable temperature.
# * Quality can vary.
# * Potential odour/pest problems if poorly managed.
#
# ---
#
# # 12. Comparison of composting methods
